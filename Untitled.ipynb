# %%
import pickle
pk1_file2 = open('butterfly_forecast.pck1','rb')
butterfly_forecast = pickle.load(pk1_file2)

# %%
pk1_file3 = open('butterfly_model.pck1','rb')
model = pickle.load(pk1_file3)

# %%
future = model.make_future_dataframe(periods=365)

# %%
forecast = model.predict(future)

# %%
model.plot(butterfly_forecast)
